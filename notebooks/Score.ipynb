# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta

# --- 1단계: 모든 개별 이슈의 '원시 점수'를 계산하는 함수 (변경 없음) ---
def calculate_raw_metrics(news_df, social_df, period_start_date, period_end_date):
    """
    [명세서 기준 수정 완료]
    - V, G, A: 'period_end_date' 이전의 '전체' 뉴스 데이터를 사용
    - P: 'period_start_date' ~ 'period_end_date' 사이의 '기간 내' 뉴스 데이터만 사용
    - C, B: 'period_start_date' ~ 'period_end_date' 사이의 '기간 내' 소셜 데이터만 사용
    """
    news_full_history = news_df[news_df['timestamp'] <= period_end_date]
    news_in_period = news_df[(news_df['timestamp'] >= period_start_date) & (news_df['timestamp'] <= period_end_date)]
    social_in_period = social_df[(social_df['timestamp'] >= period_start_date) & (social_df['timestamp'] <= period_end_date)]

    if news_full_history.empty and social_in_period.empty:
        return pd.DataFrame()

    all_issue_ids = pd.concat([news_full_history['issue_id'], social_in_period['issue_id']]).unique()
    issue_metrics = {}

    for issue in all_issue_ids:
        # --- V, G, A: '전체 기간' 뉴스 데이터 기반 계산 ---
        news_issue_history = news_full_history[news_full_history['issue_id'] == issue].copy()
        v_score, g_score, a_score = 0.0, 0.0, 0.0
        if not news_issue_history.empty:
            half_life = 7.0
            news_issue_history['days_ago'] = (period_end_date - news_issue_history['timestamp']).dt.total_seconds() / (24 * 3600)
            news_issue_history['weight'] = np.exp(-np.log(2) * news_issue_history['days_ago'] / half_life)
            v_score = news_issue_history['weight'].sum()

            news_issue_history['week'] = news_issue_history['timestamp'].dt.to_period('W')
            weekly_volume = news_issue_history.groupby('week')['weight'].sum().to_timestamp().resample('W').sum().fillna(0)
            
            v_week_0 = weekly_volume.iloc[-1] if len(weekly_volume) > 0 else 0
            v_week_1 = weekly_volume.iloc[-2] if len(weekly_volume) > 1 else 0
            v_week_2 = weekly_volume.iloc[-3] if len(weekly_volume) > 2 else 0
            
            g_score = (v_week_0 - v_week_1) / v_week_1 if v_week_1 > 0 else v_week_0
            g_previous = (v_week_1 - v_week_2) / v_week_2 if v_week_2 > 0 else v_week_1
            a_score = g_score - g_previous

        # --- P: '기간 내' 뉴스 데이터 기반 계산 ---
        news_issue_in_period = news_in_period[news_in_period['issue_id'] == issue]
        p_score = 0.0
        if not news_issue_in_period.empty:
            total_days_in_period = (period_end_date - period_start_date).days + 1
            days_with_mentions = news_issue_in_period['timestamp'].dt.normalize().nunique()
            p_score = days_with_mentions / total_days_in_period if total_days_in_period > 0 else 0

        # --- C, B: '기간 내' 소셜 데이터 기반 계산 ---
        social_issue_in_period = social_in_period[social_in_period['issue_id'] == issue]
        c_score, b_score = 0.0, 0.0
        if not social_issue_in_period.empty:
            sentiment_counts = social_issue_in_period['label'].value_counts()
            pos_count = sentiment_counts.get('찬성_개정강화', 0) + sentiment_counts.get('찬성_폐지완화', 0)
            neg_count = sentiment_counts.get('반대_현상유지', 0)
            neu_count = sentiment_counts.get('중립', 0)
            
            total_polarized = pos_count + neg_count
            if total_polarized > 1:
                balance_factor = 1 - abs(pos_count - neg_count) / total_polarized
                c_score = total_polarized * balance_factor
            else:
                c_score = 0
            b_score = total_polarized + neg_count

        issue_metrics[issue] = {'V': v_score, 'P': p_score, 'G': g_score, 'A': a_score, 'C': c_score, 'B': b_score}

    return pd.DataFrame.from_dict(issue_metrics, orient='index')


# --- 2단계: '법안' 이슈를 그룹화하고 최종 TOP 5를 계산하는 함수 (변경 없음) ---
def analyze_legislation_top5(raw_metrics_df, legislation_mapping_df):
    if raw_metrics_df.empty or legislation_mapping_df.empty:
        return pd.DataFrame()

    merged_df = raw_metrics_df.merge(legislation_mapping_df, left_index=True, right_on='issue_id', how='inner')
    
    if merged_df.empty or 'legislation_id' not in merged_df.columns:
        return pd.DataFrame()
        
    agg_logic = {
        'V': 'sum', 'P': 'max', 'G': 'mean',
        'A': 'mean', 'C': 'sum', 'B': 'sum'
    }
    aggregated_metrics = merged_df.groupby('legislation_id').agg(agg_logic)

    if len(aggregated_metrics) == 0:
        return pd.DataFrame()

    scaler = MinMaxScaler()
    normalized_metrics = scaler.fit_transform(aggregated_metrics) if len(aggregated_metrics) > 1 else np.full_like(aggregated_metrics, 0.5, dtype=float)

    normalized_df = pd.DataFrame(normalized_metrics, columns=aggregated_metrics.columns, index=aggregated_metrics.index)
    
    weights = {'V': 0.2, 'P': 0.1, 'G': 0.15, 'C': 0.25, 'B': 0.2, 'A': 0.1}
    normalized_df['IIS'] = sum(normalized_df[col] * weights[col] for col in weights)
    
    def assign_grade(score):
        if score >= 0.7: return 'High'
        elif score >= 0.4: return 'Medium'
        else: return 'Low'
    normalized_df['Grade'] = normalized_df['IIS'].apply(assign_grade)

    return normalized_df.sort_values(by='IIS', ascending=False).head(5)

# --- [MAIN EXECUTION] ---
if __name__ == "__main__":
    # 1. 파일 경로 설정
    news_data_file = 'final_merged_data.csv'
    social_data_file = 'news_comments_all_감성분석완료.csv'
    legal_text_file = 'Law_total.csv' # [추가] 법률 내용 파일 경로
    
    try:
        print(f"'{news_data_file}' 파일을 불러오는 중...")
        news_raw_df = pd.read_csv(news_data_file, dtype={'date': str})
        
        print(f"'{social_data_file}' 파일을 불러오는 중...")
        social_raw_df = pd.read_csv(social_data_file, dtype={'comment_date': str})
    except FileNotFoundError:
        print("❌ 오류: CSV 파일을 찾을 수 없습니다. 예시 데이터로 실행합니다.")

    # 2. 데이터 전처리
    print("\n데이터 전처리를 시작합니다...")
    print(f"필터링 전 원본 뉴스 데이터 행 수: {len(news_raw_df)}")
    condition_to_exclude = (news_raw_df['mapped_law'] == '해당 없음') & (news_raw_df['mapped_article'] == '해당 없음')
    news_raw_df = news_raw_df[~condition_to_exclude].copy()
    print(f"'해당 없음' 법안을 제외한 유효 뉴스 데이터 행 수: {len(news_raw_df)}")

    news_df = news_raw_df.rename(columns={'cluster_event_name': 'issue_id', 'date': 'timestamp'})
    format_string = '%Y%m%d%H%M%S'
    news_df['timestamp'] = pd.to_datetime(news_df['timestamp'], format=format_string, errors='coerce')
    news_df.dropna(subset=['timestamp', 'issue_id', 'mapped_law', 'mapped_article'], inplace=True)

    social_df = social_raw_df.rename(columns={'cluster_event_name': 'issue_id', 'comment_date': 'timestamp'})
    social_df['timestamp'] = pd.to_datetime(social_df['timestamp'], format=format_string, errors='coerce')
    social_df.dropna(subset=['timestamp', 'issue_id', 'label'], inplace=True)

    # 3. '법안 식별자' 및 매핑 테이블 생성
    print("\n'법안 식별자' (legislation_id)를 생성합니다...")
    news_df['legislation_id'] = news_df['mapped_law'] + " " + news_df['mapped_article']
    legislation_mapping_df = news_df[['issue_id', 'legislation_id']].drop_duplicates()
    
    print("--- 생성된 법안 매핑 정보 (샘플) ---")
    print(legislation_mapping_df.head())

    # 4. 전체 기간 설정 및 분석 실행
    all_dates = pd.concat([news_df['timestamp'], social_df['timestamp']])
    if all_dates.empty:
        print("분석할 날짜 데이터가 없습니다.")
    else:
        period_start = all_dates.min()
        period_end = all_dates.max()

        print("\n\n" + "="*50)
        print(f"      전체 기간 최종 '법안' TOP 5 (기간: {period_start.date()} ~ {period_end.date()})")
        print("="*50)
        
        raw_metrics = calculate_raw_metrics(news_df, social_df, period_start, period_end)
        final_top_5 = analyze_legislation_top5(raw_metrics, legislation_mapping_df)
        
        if final_top_5.empty:
            print("분석할 '법안' 관련 데이터가 없습니다.")
        else:
            # --- [기능 추가 1] TOP 5 순위표 출력 ---
            print("--- [요약] TOP 5 순위표 ---")
            print(final_top_5)

            # --- [기능 추가 2] 법안별 상세 내용 및 관련 사건 조회 ---
            print("\n\n" + "="*70)
            print("      TOP 5 법안 상세 분석 (관련 사건 및 법률 내용)")
            print("="*70)

            try:
                legal_df = pd.read_csv(legal_text_file, encoding='utf-8-sig')
                legal_df['legislation_id'] = legal_df['법률명'].astype(str) + " " + legal_df['조 번호'].astype(str)
                legal_content_available = True
            except FileNotFoundError:
                print(f"⚠️ 경고: 법률 내용 파일('{legal_text_file}')을 찾을 수 없어, 법안 내용은 생략됩니다.")
                legal_content_available = False
            except KeyError as e:
                print(f"⚠️ 경고: 법률 내용 파일에 필요한 열({e})이 없습니다. 법안 내용은 생략됩니다.")
                legal_content_available = False

            top_5_ids = final_top_5.index.tolist()
            for rank, leg_id in enumerate(top_5_ids, 1):
                print(f"\n--- [ {rank}위 ] {leg_id} ---")
                
                # 관련 주요 사건 목록 출력
                associated_events = legislation_mapping_df[legislation_mapping_df['legislation_id'] == leg_id]['issue_id'].tolist()
                if associated_events:
                    print("▶ 관련 주요 사건:")
                    for event in associated_events:
                        print(f"  - {event}")
                else:
                    print("▶ 관련 주요 사건: (정보 없음)")

                # 법률 내용 출력
                if legal_content_available:
                    content_row = legal_df[legal_df['legislation_id'] == leg_id]
                    if not content_row.empty:
                        # '조제목'과 '조내용' 열이 있는지 확인 후 출력
                        if '조제목' in content_row.columns and pd.notna(content_row.iloc[0]['조제목']):
                            print(f"▶ 조제목: {content_row.iloc[0]['조제목']}")
                        if '조내용' in content_row.columns and pd.notna(content_row.iloc[0]['조내용']):
                            print(f"▶ 조내용:\n{content_row.iloc[0]['조내용']}")
                        else:
                             print("▶ 조내용: (내용 정보 없음)")
                    else:
                        print("▶ 조내용: (일치하는 법안 정보를 찾을 수 없음)")
                
                print("-" * 50)
# Out:
# 'final_merged_data.csv' 파일을 불러오는 중...
# 'news_comments_all_감성분석완료.csv' 파일을 불러오는 중...
#
# 데이터 전처리를 시작합니다...
# 필터링 전 원본 뉴스 데이터 행 수: 27969
# '해당 없음' 법안을 제외한 유효 뉴스 데이터 행 수: 25850
#
# '법안 식별자' (legislation_id)를 생성합니다...
# --- 생성된 법안 매핑 정보 (샘플) ---
#                      issue_id               legislation_id
# 0      BDC 도입 자본시장법 개정안 통과 사건     자본시장과 금융투자업에 관한 법률 제81조
# 12       박규리 전 연인 코인 사기 연루 의혹    자본시장과 금융투자업에 관한 법률 제178조
# 83       상법 개정안 이사 충실의무 확대 논란     자본시장과 금융투자업에 관한 법률 제96조
# 1428  이재용 삼성 무죄 판결 및 자본시장법 개정  자본시장과 금융투자업에 관한 법률 제165조의4
# 1470       공매도 재개 및 무차입 방지 조치  자본시장과 금융투자업에 관한 법률 제180조의6
#
#
# ==================================================
#       전체 기간 최종 '법안' TOP 5 (기간: 2025-01-01 ~ 2025-10-30)
# ==================================================
# --- [요약] TOP 5 순위표 ---
#                                     V         P         G         A         C  \
# legislation_id
# 자본시장과 금융투자업에 관한 법률 제96조      0.022844  1.000000  0.137251  0.285807  1.000000
# 자본시장과 금융투자업에 관한 법률 제178조의2   1.000000  0.823529  0.225300  0.298383  0.481576
# 아동복지법 제17조                   0.190624  0.352941  0.337674  0.300825  0.343075
# 중대재해 처벌 등에 관한 법률 제2조         0.303280  0.248366  0.213964  0.348953  0.270648
# 정보통신망법 제70조                  0.115102  0.320261  0.102306  0.251852  0.406607
#
#                                     B       IIS   Grade
# legislation_id
# 자본시장과 금융투자업에 관한 법률 제96조      1.000000  0.603737  Medium
# 자본시장과 금융투자업에 관한 법률 제178조의2   0.453235  0.557027  Medium
# 아동복지법 제17조                   0.538384  0.347598     Low
# 중대재해 처벌 등에 관한 법률 제2조         0.382836  0.296712     Low
# 정보통신망법 제70조                  0.460610  0.289351     Low
#
#
# ======================================================================
#       TOP 5 법안 상세 분석 (관련 사건 및 법률 내용)
# ======================================================================
# ⚠️ 경고: 법률 내용 파일에 필요한 열('조번호')이 없습니다. 법안 내용은 생략됩니다.
#
# --- [ 1위 ] 자본시장과 금융투자업에 관한 법률 제96조  ---
# ▶ 관련 주요 사건:
#   - 상법 개정안 이사 충실의무 확대 논란
#   - 금융위 법인 가상자산 거래 허용
#   - 이복현 금융감독원장 주주 보호 발언
#   - 상법 개정안 부결 및 자본시장법 협의
#   - 이재명-이재용 회동 반기업 이미지 논란
#   - 민주당 정책 변화 신뢰 위기
#   - 상법 개정안 주주권리 강화 논란
#   - 코스피 5000 특별위원회 출범
#   - 법무부 상법 개정 지원 사건
#   - 주식·코인 투자사기 사건
#   - 부동산 STO 투자 현장 확인 필요성
#   - 셀리버리 상장폐지 및 자본시장법 위반 사건
# --------------------------------------------------
#
# --- [ 2위 ] 자본시장과 금융투자업에 관한 법률 제178조의2  ---
# ▶ 관련 주요 사건:
#   - 코스피 2800 돌파 및 M&A 시장 변화
#   - IPO 시장 기관투자자 제도 개선
#   - 테라-루나 가상자산 붕괴 사건
#   - 바이낸스 고파이 피해자 상환 사건
#   - STO 조각 투자 시장 활성화 사건
#   - 홈플러스 사태 금융위 엄정 대응
#   - 이재명 자본시장 활성화 간담회
#   - 트럼프 스태그플레이션 관세 발표 사건
#   - 권도형 테라폼랩스 유죄 인정 사건
#   - 이복현 금감원장 고려아연 경영권 분쟁 조사
#   - 김문수 이재명 코스피 5000 발언 논란
#   - 이재명 주식시장 불공정 거래 감시 사건
#   - 김문수 한국거래소 방문 증시부양 정책
#   - 정치테마주 부정거래 사건
#   - 남양주 비상장 주식 사기 사건
#   - 금융위 불공정거래 신상공개 방침
#   - 홈플러스 사모펀드 MBK 사기 사건
#   - 사우디 빈 살만 사기코인 사건
#   - 네이버 카페 투자사기 사건
#   - 상반기 IPO 시장 침체 및 주가 하락 사건
#   - 오리온 바이오산업 진출 사건
#   - 김건희 자본시장법 위반 사건
#   - 고려아연 유상증자 부정거래 사건
#   - 한국 증시 밸류업 정책 논의 중단 사건
#   - KB국민은행 미공개정보 주식투자 사건
#   - 일양약품 주가조작 무혐의 사건
#   - 구연경 남편 미공개 정보 주식거래 사건
#   - 텔레그램 핀플루언서 선행매매 사건
#   - 스팸 문자 주가조작 사건
#   - 이승기 장인 주가조작 사건
#   - 제약사 신약정보 부당이득 사건
#   - 전직 애널리스트 미공개 정보 이용 사건
#   - 강기혁 주식 시세조종 사건
#   - 네이버 주식카페 시세조종 사건
#   - 이재용 삼성전자 회장 무죄 판결 사건
#   - 와이더플래닛 선행매매 의혹 사건
#   - 윤관-구연경 자본시장법 위반 사건
#   - 김건희 코바나컨텐츠 협찬 의혹
#   - 김건희-컴투스 뇌물 의혹 사건
#   - 박설웅 에스디생명공학 주식 매도 무죄 사건
#   - 롯데렌탈 유상증자 주주 반발 사건
#   - 고려아연 유상증자 검찰 수사 사건
#   - 일양약품 백혈병 치료제 주가조작 무혐의 사건
#   - 일양약품 코로나19 치료제 허위 발표 사건
#   - 김건희 구속영장 심사 사건
#   - 김건희 특검 조사 사건
#   - 오세훈 조기대선 준비 저서 출간
#   - 이춘석 의원 차명 주식거래 의혹 사건
#   - 도이치모터스 주가조작 사건
#   - 이종호 구속영장 청구 사건
#   - 윤석열 외환 혐의 군 관계자 조사
#   - 김건희 특검 출석 구속 전망
#   - 김건희 여사 공천 개입 의혹
#   - 윤석열 명태균 선거 개입 의혹
# --------------------------------------------------
#
# --- [ 3위 ] 아동복지법 제17조  ---
# ▶ 관련 주요 사건:
#   - 충북 초중등교육법 개정안 통과
#   - 아이돌 폭행 소속사 대표 사건
#   - 故김새론 녹취록 조작 의혹 사건
#   - 故김하늘 양 악성댓글 사건
#   - 불법 입양 브로커 조직의 실체
#   - 윤석열 이주호 리박스쿨 고발 사건
#   - 김수현 별그대 브라질 방영 사건
#   - 故김새론-김수현 그루밍 의혹
#   - 김수현 스타랭킹 1위 사생활 논란
#   - 강경윤 기자 가세연 김세의 고소 사건
#   - 양주 태권도장 5세 아동 사망 사건
#   - 청주 의붓아들 학대 사망 사건
#   - 의붓아들 학대 사망 및 친자식 불법입양 사건
#   - 대구 신생아 불법 입양 사건
#   - 광주 아동 방임 사건
#   - 인천 신생아 유기 사건
#   - 전북 중학생 아동학대 사망 사건
#   - 내연녀 아동 유기 공무원 사건
#   - 제주 아기 베이비박스 유기 사건
#   - 춘천 아동 방임 및 정보통신망 범죄 사건
#   - 인천 생후 83일 아기 질식사 사건
#   - 인천 11살 아들 학대치사 사건
#   - 전남 해남 신생아 유기 사건
#   - 광주 신생아 유기 사건
#   - 광주 아동 방임 실명 사건
#   - 남양주 아기 방임 사망 사건
#   - 광주 생후 3개월 딸 아동매매 사건
#   - 인천 초등생 화재 사망 사건
#   - 전주 70대 폭행 20대 벌금형 사건
#   - 전남 장흥 아동 방임 화재 사건
#   - 광주 5세 입양아 화재 사망 사건
#   - 전남 여수 쌍둥이 살해 사건
#   - 조지아주 아동 방치 사건
#   - 군산 의붓아들 폭행 사망 사건
#   - 대구 신생아 중환자실 간호사 학대 사건
#   - 유명 무용가 제자 성추행 사건
#   - 울산 수영강사 아동학대 사건
#   - 세종시 어린이집 교사 폭행 사건
#   - 횡단보도 아동학대 사건
#   - 춘천 60대 아동복지법 위반 사건
#   - 아프리카 선교센터 아동학대 사건
#   - 김포 반려견 창밖 투척 사건
#   - 세종시 초등학생 성매수 사건
#   - 대구 피겨코치 아동학대 사건
#   - 해남 태권도장 아동 폭행 사건
#   - 제주 펜싱 지도자 아동 폭행 추행 사건
#   - 부산 유도회장 아동학대 사건
#   - 대법원 아동 성적 학대 사건
#   - 인천 초등학교 장애학생 폭행 사건
#   - 인천 사실혼 폭행 및 아동학대 사건
#   - 울산 초등생 앞 아내 폭행 사건
#   - 국힘 선거운동원 여중생 성희롱 사건
#   - 광주 친모 아동학대 사건
#   - 인천 아이돌보미 아동학대 사건
#   - 청주 초등생 정서적 학대 사건
#   - 부산 국공립어린이집 장애아 학대 사건
#   - 세종시 유치원생 폭행 사건
#   - 인천 초등생 협박 아동학대 사건
#   - 부산 축구교실 아동학대 사건
#   - 티아라 전 멤버 이아름 사기 사건
#   - 춘천 아동학대 40대 엄마 사건
#   - K-팝 연수업체 성추행 사건
#   - 인천 사제 총기 가족 살해 사건
#   - 인천 아동 정서적 학대 사건
#   - 강원 원주 학원차 아동 성범죄 사건
#   - 전주 유치원 교사 아동 학대 사건
#   - 부산 축구교실 감독 아동폭언 사건
#   - 성남 여성 운전자 음란행위 사건
#   - 리박스쿨 아동 정서학대 고발 사건
#   - 리박스쿨 댓글조작 및 고발 사건
#   - 리박스쿨 아동복지법 위반 사건
#   - 의왕 초등학교 담임교사 폭행 사건
#   - 미성년자 성 착취물 제작 사건
#   - 30대 미성년자 성착취물 제작 사건
#   - 동성 제자 성추행 무용가 징역 4년
#   - 층간소음 협박 및 재물손괴 사건
#   - 고등학교 태권도부 폭행 사건
#   - 제주 고교 교사 성희롱 사건
#   - 김녹완 성착취 조직 사건
#   - 창원 아내 가스라이팅 폭행 사건
#   - 티아라 이아름 아동학대 명예훼손 사건
#   - 인천 여중생 폭행 사건
#   - 서울 강서구 식당 흉기 위협 사건
#   - 리박스쿨 늘봄학교 교육 의혹
#   - 초등생 살해 협박 사건
#   - 충북 교육활동 침해 사건
#   - 아내 잔소리와 부재중전화 사건
#   - 이재명 교권 보호 정책 요구 사건
#   - 아이 키우기 어려운 한국 사회 문제
#   - 소년병 동원 아동 정서적 학대 사건
# --------------------------------------------------
#
# --- [ 4위 ] 중대재해 처벌 등에 관한 법률 제2조  ---
# ▶ 관련 주요 사건:
#   - 로펌 매출 성장 경쟁 사건
#   - 부산 반얀트리 호텔 화재 사건
#   - 강남 은마아파트 공사 매몰사고
#   - 한솔제지 노동자 추락사 사건
#   - 울산 HDC현산 작업자 익사 사고
#   - 부산 반얀트리 공사장 화재 사고
#   - DL건설 아파트 근로자 추락사고
#   - 반얀트리 해운대 화재 참사
#   - 서울 청담동 가스 폭발 사고
#   - 태안화력 하청노동자 사망 사건
#   - 안성 고속도로 교량 붕괴 사고
#   - 김해 산소치료기 폭발사고
#   - 전남 장성 에어컨 설치 노동자 사망 사건
#   - 인천 맨홀 작업자 사망 사고
#   - 중대재해처벌법 시행 3주년 논란
#   - 부산신항 홋줄 사고 노동자 사망
#   - 안성 고속도로 공사장 붕괴 사고
#   - 기아차 광주공장 근로자 사망 사건
#   - 이천 물류센터 대형 화재 사건
#   - 천안 공사 현장 중대재해 점검 사건
#   - 현대엔지니어링 아산 건설 현장 사망사고
#   - 동대문 철거 현장 건물 붕괴 사고
#   - 서울 동대문구 철근 사고 사망 사건
#   - 청담동 공사장 가스 폭발 사고
#   - 이문동 아파트 건설사고 사망 사건
#   - 경주 사료공장 외국인 노동자 사망 사건
#   - 고성 저수탱크 수자원공사 직원 사고
#   - 세종-포천고속도로 교량 붕괴 사건
#   - 영풍 석포제련소 환경법 위반 사건
#   - 안성 고속도로 교각 붕괴사고
#   - 부산 기장군 리조트 화재 사망 사건
#   - 영암 주택 지붕 작업자 추락 사망 사건
#   - 제주 골프장 근로자 사망 사고
#   - 화정아이파크 붕괴 사고 행정처분
#   - 영풍-고려아연 경영권 분쟁 사건
#   - 정보통신공사 맨홀 질식사고 예방 점검
#   - 포스코 저녁 회식 금지 사건
#   - 영천 화장품공장 폭발 사고
#   - 동서발전 동해화력 근로자 추락 사망 사건
#   - 포스코이앤씨 의령 중대재해 사고
#   - 동해화력발전소 노동자 추락사 사건
#   - 한솔제지 신입사원 사망 사건
#   - 은마아파트 하수관 공사 사망 사건
#   - 인천 맨홀 작업자 가스중독 사망 사건
#   - 현대비앤지스틸 중대재해 사건
#   - 전북 산업현장 노동자 추락사고
#   - 태안 화력발전소 노동자 사망사고
#   - SPC삼립 시화 공장 노동자 사망 사건
#   - 태안 화력발전소 하청 노동자 사망사고
#   - 삼성중공업 하청 근로자 사망 사고
#   - 건설현장 노동자 사망사고 간담회
#   - OCI 군산공장 협력사 안전간담회
#   - 강원농협 2025 경영전략회의
#   - 대한안전교육협회 MSDS 키오스크 도입
#   - LS일렉트릭 AI 안전관제 플랫폼 출시
#   - 에스넷-에스알 AI 안전관리 시스템 협약
#   - 광주 산업재해 노동자 사망 사건
#   - 중소기업 제조업 부흥 정책 논의
#   - 김문수 중대재해처벌법 비판 사건
#   - 노동정책 변화와 산업계 대응 방안 논의
#   - 이재명 대통령 산업재해 사망사고 대책
#   - 산재 예방 강화를 위한 정부 대책
#   - 강원농협 경영전략회의 개최
#   - 민주노동당 김용균 재단 정책협약
#   - 중소기업 공약 실효성 논란
#   - 경북 도로공사 벌목 사고 사망
#   - 중대재해처벌법 로펌 대응 사건
#   - 성동구 사업장 안전 점검 사건
#   - 광주교육청 중대재해 예방 길라잡이 발간
#   - 행복청 중대재해 예방 점검
#   - 중소 건설업 안전관리 개선 토론회
#   - 대구·경북 산업재해 사망 증가 사건
#   - 경기 GH 스마트 안전관리 시스템 개발 사건
#   - 경남 중대재해 예방 안전관리 강화
#   - 태안군 안전전문감시원 양성 사건
#   - 중대재해처벌법 효과성 조사 사건
#   - 산재 안전 강화 여론 조사
#   - 산업재해 전담 수사팀 신설 사건
#   - 충북 노동자 사망사고 및 중대재해처벌법 논란
#   - 포스코이앤씨 산업재해 사망사고
#   - 유통업계 안전관리 강화 조치
#   - 청년 노동자 권리 보장 촉구 기자회견
#   - 인천환경공단 맨홀 사망 사건
#   - 구미 이주노동자 폭염 사망 사건
#   - 육군 스마트안전 세미나 개최
#   - 경남 이주노동자 폭염 사망 사건
#   - 아리셀 중대재해 참사 1주기
#   - 양대노총 공공부문 노동자 집회
#   - 중대시민재해 관리 미흡 사건
#   - 산청 대형 산불 발화 원인 조사
#   - 강동구 싱크홀 중대재해 문제
#   - 오산 옹벽 붕괴 사망사고
#   - 창원 NC파크 야구장 구조물 사고
#   - 창원 NC파크 야구장 구조물 추락 사망 사건
#   - 영남권 산불 동물 구조 사건
#   - 창원NC파크 안전점검 재개장 사건
#   - 2025 대한민국 전기산업엑스포 개최
#   - 서울 강동구 싱크홀 사고
#   - 케이에스건설 중대재해배상공제 가입
#   - 아리셀 화재 참사 유가족의 싸움
#   - 설난영 노조 발언 논란 사건
#   - 여야 민생 공통공약 법안 처리 논의
#   - 광양국가산단 화재감시 시스템 보급
#   - 포스코이앤씨 중대재해 징계 검토
#   - 노란봉투법 재추진 논란
#   - 중대재해처벌법 건설업 해석 논란
#   - 권영국 대선 후보 불평등 대개혁 주장
#   - 삼성물산 건설안전 연구소 안전사고 감소 사건
#   - 정약용 목민심서 행정 철학
#   - 방송국 비정규직 노동자 사망 사건
#   - 서울 마포구 건설현장 추락사
#   - 허윤정 외상센터 의료진 보호 필요성
#   - 인천시 청렴도 최하위 비리 사건
#   - 한정애 부동산 공급대책 발표
#   - 포스코 중대재해와 K-스틸법 논란
#   - 오륜교회 방송팀장 과로사 사건
#   - 산재 사망 1명 입찰 제한 논의
#   - 윤석열 정부 기업규제 법안 논란
#   - 이재명 중대재해 근절 대책 회의
#   - 산업재해 유가족의 투쟁 사건
#   - 보령 중대재해 예방 교육 실시
#   - 최태원 AI 노동 환경 변화 발언
#   - 인천 드론 청소 시범사업
#   - 인천 맨홀 작업자 질식 사고
#   - 비정규직 고용불안 문제
#   - 이재명 대통령 국무회의 지시 사항
#   - 한용현 노동법 칼럼 50화 사건
#   - 삼척상공회의소 중대재해 교육 사건
# --------------------------------------------------
#
# --- [ 5위 ] 정보통신망법 제70조  ---
# ▶ 관련 주요 사건:
#   - A사 기밀정보 유출 사건
#   - 아내 택시기사와 불륜 의혹 사건
#   - 의대생 협박글 수사 사건
#   - 넥슨 집게손가락 온라인 괴롭힘 사건
#   - 김수현 악플러 고소 사건
#   - 무안 제주항공 참사 악성 게시글 사건
#   - 김새론 악플 피해 사건
#   - 나는 솔로 16기 상철 영숙 명예훼손 사건
#   - 나경원-안철수 명예훼손 고발 사건
#   - 민주노총 경찰 혼수상태 허위사실 사건
#   - 김건희 여사 쥴리 의혹 사건
#   - 허위조작정보 처벌 강화 법안
#   - 윤석열 국민변호인단 시민단체 고발 사건
#   - 이재명 아들 험담 금지법 논란
#   - 신평 변호사 법관 명예훼손 사건
#   - 김동성 양육비 미지급 명예훼손 사건
#   - 지드래곤 악플러 법적 대응 사건
#   - 복학 의대생 비난 사건
#   - 안민석 최서원 명예훼손 사건
#   - 최강욱 이동재 명예훼손 사건
#   - 이영애 김건희 연관 주장 유튜버 벌금 사건
#   - 제주항공 여객기 참사 허위사실 유포 사건
#   - 신용한 교수 대통령실 고발 사건
#   - 이하늘 명예훼손 사건
#   - JK김동욱 이재명 허위사실 유포 고발 사건
#   - 故김하늘 양 악플러 고소 사건
#   - 영탁 명예훼손 사건
#   - 전한길 내란선동 고발 사건
#   - 김수현 악성 루머 고소 사건
#   - 김건희 여사 고소 사건
#   - 대전 초등생 피살 사건 허위사실 유포
#   - 문형배 헌법재판소장 음란물 시위 사건
#   - 사이버 명예훼손 처벌 강화 사건
#   - 유시민 명예훼손 고발 사건
#   - 이상민 자택 현금 발견 사건
#   - 한동훈 명예훼손 황희석 징계 사건
#   - 주주 채팅방 전 이사 명예훼손 무죄 사건
#   - 민희진-하이브 손해배상 소송
#   - 가세연 조국 가족 허위사실 배상 사건
#   - 민희진 어도어 전 직원 명예훼손 소송
#   - 명태균 여론조사 비용 대납 의혹
#   - 진혜원 검사 김건희 명예훼손 사건
#   - 최경환 신라젠 허위제보 사건
#   - 송하윤 학폭 의혹 법적 대응 사건
#   - 임현택 의협 회장 명예훼손 사건
#   - 이준석 성상납 의혹 고발 사건
#   - 임성근 구명로비 제보자 명예훼손 사건
#   - 허웅 전 여친 변호사 고소 사건
#   - 하이브 아티스트 명예훼손 사건
#   - 청담동 술자리 의혹 손해배상 사건
#   - 윤석열 명예훼손 검찰 무혐의 사건
#   - 신애라 가짜뉴스 사망설 논란
#   - 제주항공 참사 사이버 명예훼손 사건
#   - 대통령실 유튜버 고발 사건
#   - 무안 제주항공 참사 악플 사건
#   - 리박스쿨 댓글 조작 사건
#   - 김부선 악플 및 스토킹 피해 사건
#   - 국민의힘 내란죄 공범 허위사실 유포 사건
#   - 최태원 허위사실 유포 사건
#   - 윤석열 명예훼손 언론 보도 사건
#   - 윤석열 고발사주 의혹 사건
#   - 나는 SOLO 16기 영숙 명예훼손 사건
#   - 이진숙 종군기자 허위 경력 사건
#   - 황철순 아내 폭행 고소 사건
#   - 황철순 아내 상해 고소 사건
#   - 김수현 미성년자 교제 의혹 사건
#   - 뉴진스 팬덤 명예훼손 고발 사건
#   - 명예훼손 고소 남발 사건
#   - 최정원 상간남 소송 시간 끌기 의혹
#   - 최정원 불륜 소송 연기 사건
#   - JTBC 서부지법 난동 허위사실 유포 사건
#   - 이준석 의원직 제명 청원 사건
#   - 탄핵 찬성 식당 허위 사실 유포 사건
#   - 이준석 의원 제명 청원 역대 2위
#   - JK 김동욱 국민의힘 전당대회 불참 사건
#   - 故 김새론 매니저 권영찬 고소 사건
#   - 나는 SOLO 영숙 상철 사생활 폭로 사건
#   - 영숙 명예훼손 벌금형 사건
#   - 영숙 명예훼손 사건
#   - 류희림 청부민원 의혹 사건
#   - 사실적시 명예훼손죄 폐지 청원
#   - 이낙연 명예훼손 열린공감TV 사건
#   - 성남시의회 이영경 의원 자녀 학폭 고소 사건
#   - 대전 초등학생 피살 사건 허위사실 유포
#   - 이상민 전 장관 자택 압수수색 허위보도 사건
#   - 이상민 전 장관 현금 다발 발견 논란
#   - 이상민 전 장관 현금 다발 허위보도 사건
#   - 이상민 전 장관 자택 현금 발견 사건
#   - 이진숙 방통위 허위사실 고발 사건
#   - 이상민 자택 돈다발 발견 의혹
#   - 유시민 강선우 갑질 의혹 고발 사건
#   - 유시민 강선우 갑질 논란 고발 사건
#   - 유시민 보좌관 갑질 논란
#   - 박준환 아이딧 데뷔 하차 사건
#   - 이진숙 방통위원장 허위사실 유포 사건
#   - 김문수 유시민 발언 논란
#   - 이재명 아들 군 면제 가짜뉴스 사건
#   - 이수정 SNS 허위정보 명예훼손 사건
#   - 이재명 병역 허위사실 유포 사건
#   - 이수정 가짜뉴스 논란 사건
#   - 가짜뉴스 유포 검찰 구속 사건
#   - 김수현 AI 녹취록 위조 사건
#   - 사이버레커 허위정보 유포 사건
#   - 제주항공 참사 허위사실 유포 사건
#   - 유시민 설난영 발언 논란 사건
#   - 정구정 세무사회 비방 유인물 사건
#   - 박명수 김건모 성폭행 사건
#   - 장시호 위증 교사 의혹 사건
#   - 고려아연 악성 댓글 조직적 비방 사건
#   - 대전 초등생 김하늘 명예훼손 사건
#   - 국민의힘 촉법소년 연령 하향 공약
#   - 지니틱스 허위사실 유포 사건
#   - AI안전연구소-카카오 딥페이크 탐지 기술 개발
#   - 국민의힘 촉법소년 연령 하향 사건
#   - 강력범죄 처벌 강화 공약
#   - 국민의힘 강력범죄 안전 공약
#   - 이재명 내각 인선 논란
#   - 김문수 수도권 유세 교육 공약
# --------------------------------------------------
